# %% [markdown]
# ## Module 2 HW

# %% [markdown]
# In case you don't get one option exactly, select the closest one
#
# For the homework, we'll be working with the green taxi dataset located here:
#
# https://github.com/DataTalksClub/nyc-tlc-data/releases/tag/green/download
#
# To get a wget-able link, use this prefix (note that the link itself gives 404):
#
# https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/
#
# Assignment
# So far in the course, we processed data for the year 2019 and 2020. Your task is to extend the existing flows to include data for the year 2021.

# %% [markdown]
# ---

# %% [markdown]
# As a hint, Kestra makes that process really easy:
#
# You can leverage the backfill functionality in the scheduled flow to backfill the data for the year 2021. Just make sure to select the time period for which data exists i.e. from 2021-01-01 to 2021-07-31. Also, make sure to do the same for both yellow and green taxi data (select the right service in the taxi input).
# Alternatively, run the flow manually for each of the seven months of 2021 for both yellow and green taxi data. Challenge for you: find out how to loop over the combination of Year-Month and taxi-type using ForEach task which triggers the flow for each combination using a Subflow task.

# %% [markdown]
# ---

# %% [markdown]
# ### Question 1

# %% [markdown]
# Within the execution for Yellow Taxi data for the year 2020 and month 12: what is the uncompressed file size (i.e. the output file yellow_tripdata_2020-12.csv of the extract task)?

# %% [markdown]
# Answer: `134.5 MiB`

# %% [markdown]
# ---

# %% [markdown]
# ### Question 2

# %% [markdown]
# What is the rendered value of the variable file when the inputs taxi is set to green, year is set to 2020, and month is set to 04 during execution?

# %% [markdown]
# First, I edited the inputs when executing the flow...

# %% [markdown]
# <img src="supplements/images/execute.png"
#      alt="Here is where I chose the new inputs."
#      width="550">

# %% [markdown]
# Then, I went to the Overview panel to view the name of the file...

# %% [markdown]
# <img src="supplements/images/file_name.png"
#      alt="Here is where I found the file name."
#      width="550">

# %% [markdown]
# Answer: `green_tripdata_2020-04.csv`

# %% [markdown]
# ---

# %% [markdown]
# ### Question 3

# %% [markdown]
# How many rows are there for the Yellow Taxi data for all CSV files in the year 2020?

# %% [markdown]
# I manually ran Flow #4 for each month in 2020, then queried the database as shown below:

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
query = text("""
SELECT COUNT(*) FROM yellow_tripdata WHERE filename LIKE 'yellow_tripdata_2020%';
""")

# %%
with engine.connect() as conn:
    df_result = pd.read_sql(query, conn)
    print(df_result)
# Out:
#       count
# 0  24648499

# %% [markdown]
# Answer: `24,648,499`

# %% [markdown]
# ---

# %% [markdown]
# ### Question 4

# %% [markdown]
# How many rows are there for the Green Taxi data for all CSV files in the year 2020?

# %% [markdown]
# I manually ran Flow #4 for each month in 2020, then queried the database as shown below:

# %%
query = text("""
SELECT COUNT(*) FROM green_tripdata WHERE filename LIKE 'green_tripdata_2020%';
""")

# %%
with engine.connect() as conn:
    df_result = pd.read_sql(query, conn)
    print(df_result)
# Out:
#      count
# 0  1734051

# %% [markdown]
# Answer: `1,734,051`

# %% [markdown]
# ---

# %% [markdown]
# ### Question 5

# %% [markdown]
# How many rows are there for the Yellow Taxi data for the March 2021 CSV file?

# %% [markdown]
# First, I simply edited the YAML for Flow #4 to reference 2021 instead of 2019 & 2020:

# %% [markdown]
# <img src="supplements/images/yaml_flow.png"
#      alt="Here is where I edited the flow."
#      width="550">

# %% [markdown]
# Then I queried the database as before:

# %%
query = text("""
SELECT COUNT(*) FROM yellow_tripdata WHERE filename LIKE 'yellow_tripdata_2021-03%';
""")

# %%
with engine.connect() as conn:
    df_result = pd.read_sql(query, conn)
    print(df_result)
# Out:
#      count
# 0  1925152

# %% [markdown]
# Answer: `1,925,152`

# %% [markdown]
# ---

# %% [markdown]
# ### Question 6

# %% [markdown]
# How would you configure the timezone to New York in a Schedule trigger?

# %% [markdown]
# This is clearly delineated in Kestra's docs: https://kestra.io/docs/workflow-components/triggers/schedule-trigger

# %% [markdown]
# <img src="supplements/images/timezone.png"
#      alt="Here is how timezones are defined in Kestra."
#      width="550">

# %% [markdown]
# Answer: `Add a timezone property set to America/New_York in the Schedule trigger configuration.`

# %% [markdown]
# ---
